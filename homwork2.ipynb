# %% [markdown]
# ### Bài 1: Nhập vào 2 cạnh củamột hình chữ nhật. In ra màn hình diện tích và chu
# vi của nó.

# %%
a, b= map(int,input().split())
s=a*b
c= (a+b)*2
print(s,c)
# Out:
# 24 20

# %% [markdown]
# ### Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của
# nó.

# %%
r= int(input())
pi=3.14
s= pi*r**2
chuvi = pi*r
print(s,chuvi)
# Out:
# 28.26 9.42

# %% [markdown]
# ### Bài 3 : Tính tam giác: Nhâp vào basố a,b,c bất kì. Kiểm tra xem nó có thể là
# độ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh
# cua mot tam giac'. Ngượclại, kiểm tra xem nó là tam giác gì: Đều, Cân,
# Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giácvà in ra màn
# hình.

# %%
a, b, c = map(int,input().split())
cv = a+b+c
p= cv/2
s= (p*(p-a)*(p-b)*(p-c))**0.5
if (a+b>c) and (a+c>b) and (b+c>a):
    print("la tam giac")
    if a==b ==c :
        print("là tam giac đều")
    elif a==b or a==c or b==c :
        print("tam giac can ")
    elif a**2== b**2+ c**2 or b**2== a**2+c**2 or c**2== a**2+b**2:
        print("tam giac vuong")
    else:
        print("tam giac thuong")
    print(cv , s)
else:
     print("khong la 3 canh tam giac")
# Out:
# la tam giac
# tam giac vuong
# 12 6.0

# %% [markdown]
# ### Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
def giai(a,b):
    if b == 0:
        return "Phương trình vô nghiệm"
    elif a == 0:
        return "Phương trình vô số nghiệm"
    else:
        return "Phương trình có nghiệm x = " + str(-b/a)
a =int(input())
b = int(input())
print(giai(a,b))
# Out:
# Phương trình có nghiệm x = -2.0

# %% [markdown]
# ### Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
import math
def giai(a,b,c):
    if a==0:
        if b==0:
            if c==0:
                return "phuong trinh co vo so nghiem"
            else:
                return "phuong trinh vo nghiem"
        else:
            if c==0:
                return "phuong trinh vo so nghiem"
            else:
                return "phuong trinh co nghiem duy nhat x=" + str(-c/b)
    delta = b**2 - 4*a*c
    if delta > 0:
        x1 = (-b + math.sqrt(delta)) / (2*a)
        x2 = (-b - math.sqrt(delta)) / (2*a)
        print(f"Phương trình có 2 nghiệm phân biệt:")
        print(f"x1 = {x1}")
        print(f"x2 = {x2}")
    elif delta == 0:
        x = -b / (2*a)
        print(f"Phương trình có nghiệm kép: x1 = x2 = {x}")
    else:
        print("Phương trình vô nghiệm thực.")
a=int(input())
b=int(input())
c=int(input())
print(giai(a,b,c))
# Out:
# phuong trinh vo so nghiem

# %%
import math
a = float(input("Nhập a: "))
b = float(input("Nhập b: "))
c = float(input("Nhập c: "))

if a == 0:
    if b == 0:
        print("Phương trình vô nghiệm" if c != 0 else "Vô số nghiệm")
    else:
        print(f"Nghiệm x = {-c/b}")
else:
    delta = b**2 - 4*a*c
    if delta < 0:
        print("Phương trình vô nghiệm.")
    elif delta == 0:
        print(f"Phương trình có nghiệm kép x = {-b / (2*a)}")
    else:
        x1 = (-b + math.sqrt(delta)) / (2*a)
        x2 = (-b - math.sqrt(delta)) / (2*a)
        print(f"Phương trình có 2 nghiệm phân biệt: x1 = {x1}, x2 = {x2}")
# Out:
# Phương trình vô nghiệm.

# %% [markdown]
# ### Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím)

# %%
a, b, c, d = map(int,input().split())
if a>b and a>c and a>d :
    print(a)
elif b>a and b>c and b>d :
    print(b)
elif c>a and c>b and c>d :
    print(c)
else:
    print(d)
# Out:
# 9

# %% [markdown]
# ### Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím)

# %%
a, b, c, d = map(int,input().split())
min_value = min(a, b, c, d)
print("gia tri nho nhat la:", min_value)
# Out:
# gia tri nho nhat la: 2

# %% [markdown]
# ### Bài 8: Giải hệ phương trình tuyến tính:
# ax + by = m
# cx + dy = n

# %%
a, b, m, c, d, n =map(int,input().split())
D = a * d - b * c
Dx = m * d - b * n
Dy = a * n - m * c
if D != 0:
    x = Dx / D
    y = Dy / D
    print(f"Hệ có nghiệm duy nhất: x = {x}, y = {y}")
else:
    if Dx == 0 and Dy == 0:
        print("Hệ phương trình có vô số nghiệm.")
    else:
        print("Hệ phương trình vô nghiệm.")
# Out:
# Hệ có nghiệm duy nhất: x = -4.0, y = 3.0

# %% [markdown]
# ### Bài 9: Nhập vào thời gian 1 công việc nàođó là x giây. Hãy chuyểnđổi và viết
# ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao
# nhiêu giây.

# %%
x=int(input())
h=x/3600
p=h*60
print(x,f"{h:.2f}" , f"{p:.2f}")
# Out:
# 30 0.01 0.50

# %% [markdown]
# ### Bài 10: Nhập vào tâm và bán kính của mộtđường tròn. Sauđó nhập vào một
# điểm A(x, y) bất kì và kiểm tra xem nó có thuộcđường tròn hay không?

# %%
x, y, x1, y1, r  =map(int,input().split())
d= ((x1-x)**2+(y1-y)**2)**0.5
if d==r:
    print("A nam tren duong tron")
elif d<r:
    print("A nam trong duong tron")
else:
    print("A nam ngoai duong tron")
# Out:
# A nam trong duong tron

# %% [markdown]
# ### Bài 11: Tính xy (Với x, y là số thực)

# %%
x, y = map(float,input().split())
tich = x**y
print(f"{tich:.2f}")
# Out:
# 8.00
